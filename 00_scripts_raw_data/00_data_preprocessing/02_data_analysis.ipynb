# %%
import csv
import json
import pandas as pd
from datetime import datetime
import numpy as np
from os.path import exists

from collections import Counter

outputFolders = "../data_2019_processed/"


import warnings
warnings.filterwarnings("ignore")

# %%
# Dataframe of all datasets
# initialize list of lists
datasets = [['0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs'],
            ['0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA'], 
            ['2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0'], 
            ['2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys'], 
            #['5FLZBTVAPwdq9QezHE2sVCJIs7p+r6mCemA2gp9jATk'], #does not have the file
            ['7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA'], 
            ['a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4'], 
            ['ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc'], 
            ['Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U'], 
            ['CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA'], 
            ['DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc'], 
            ['DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA'], 
            ['dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY'], 
            ['HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo'], 
            ['jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw'], 
            ['JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I'], 
            ['K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8'], 
            ['oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q'], 
            ['pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM'], 
            ['PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc'], 
            ['QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ'], 
            ['rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw'], 
            ['RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI'], 
            ['SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4'], 
            ['VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is'], 
            ['Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw'], 
            ['XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA'], 
            ['YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw'], 
            ['ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM'], 
            ['ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY']]
  
# Create the pandas DataFrame
folders = pd.DataFrame(datasets, columns=['folder'])

# %%
dataset = pd.read_csv(outputFolders+"student_oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q.csv")
#dataset = pd.read_csv(outputFolders+"student_ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM.csv")

dataset
# Out:
#        activity    location  distanceHome  showActuation   timestamp  \
# 0      Exercise  University             0          False  1526317085
# 1         Still  University             0          False  1526317793
# 2         Still  University             0          False  1526318003
# 3       Unknown  University             0          False  1526318033
# 4       Unknown  University             0          False  1526318063
# ...         ...         ...           ...            ...         ...
# 21664   Tilting       House             0          False  1528826629
# 21665     Still       House             0          False  1528826659
# 21666     Still       House             0          False  1528826689
# 21667     Still       House             0          False  1528826719
# 21668     Still       House             0          False  1528826809
#
#        time_to_next_alarm  sound  proximity  phone_lock  light day_of_week  \
# ...

# %%
test = []

for indexFolder, folder in folders.iterrows():
    dataset = pd.read_csv(outputFolders+"student_"+folder['folder']+".csv")
    
    
    data = dict()
    # basic transformations 
    print("")
    print("")
    print("")
    print("student_"+str(folder['folder'])+".csv", Counter(dataset['class']) )
    print("")
    print('location',Counter(dataset['location']))
    print('activity',Counter(dataset['activity']))
    print('day_of_week',Counter(dataset['day_of_week']))
    print('light',dataset['light'].min(),dataset['light'].sum())
    print('sound',dataset['sound'].min(),dataset['sound'].sum())
    #print('time_sleeping',Counter(dataset['time_sleeping']))
    #print('sleep_time',Counter(dataset['sleep_time']))
    #print('wakeup_time',Counter(dataset['wakeup_time']))
    print('proximity',Counter(dataset['proximity']))
    print('phone_lock',Counter(dataset['phone_lock']))
    print('class',Counter(dataset['class']))
    #print('sleep_time',Counter(dataset['sleep_time']))
    #print('wakeup_time',Counter(dataset['wakeup_time']))
    #print('timestamp',dataset['timestamp'][0],dataset['timestamp'][dataset.shape[0]-1])
    print("")
    #print('time_to_next_alarm',Counter(dataset['time_to_next_alarm']))
    print('time_to_next_alarm',dataset['time_to_next_alarm'].max())
    print("")
    print("")
    print("")
    

    
    data["student"] = folder['folder']
    #data["timestamp_start"] = dataset['timestamp'][0]
    #data["timestamp_end"] = dataset['timestamp'][dataset.shape[0]-1]
    data["light_sum"] = dataset['light'].sum()
    data["sound_sum"] = dataset['sound'].sum()
    data["phone_lock"] = Counter(dataset['phone_lock'])
    data["location"] = Counter(dataset['location'])
    data["activity"] = Counter(dataset['activity'])
    data["day_of_week"] = Counter(dataset['day_of_week'])
    data["proximity"] = Counter(dataset['proximity'])
    data["time_to_next_alarm "] = dataset['time_to_next_alarm'].max()
    data["class "] = Counter(dataset['class'])
    
    test.append(data)
# Out:
# student_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs.csv Counter({'awake': 16341, 'asleep': 1652})
#
# location Counter({'House': 9277, 'Other': 4721, 'University': 3995})
# activity Counter({'Still': 13355, 'Exercise': 1674, 'Unknown': 1362, 'In vehicle': 1081, 'Tilting': 521})
# day_of_week Counter({'Tuesday': 3681, 'Monday': 2641, 'Friday': 2533, 'Wednesday': 2462, 'Thursday': 2344, 'Sunday': 2231, 'Saturday': 2101})
# light 0 1056450
# sound 0 96608712
# proximity Counter({5: 11441, 0: 6552})
# phone_lock Counter({'locked': 9806, 'not locked': 8187})
# class Counter({'awake': 16341, 'asleep': 1652})
#
# time_to_next_alarm 604800000.0
#
#
#
#
#
#
# student_0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA.csv Counter({'awake': 8158, 'asleep': 3403})
#
# location Counter({'House': 5456, 'Other': 3654, 'University': 2451})
# activity Counter({'Unknown': 6944, 'Still': 4172, 'Exercise': 191, 'Tilting': 132, 'In vehicle': 122})
# ...

# %%
print("Starting script test")
print()
unprocessedAwake, unprocessedAsleep = 0,0
processedAwake, processedAsleep = 0,0
for indexFolder, folder in folders.iterrows():
    dataset = pd.read_csv(outputFolders+"student_"+folder['folder']+".csv")
    
    #limitAwake = 64800 # 18 hs == 1080 min == 64800 s 
    #limitAwake = 86400
    #limitAfterAwake = 64800 # 18 hs == 1080 min == 64800 s 
    #limitBeforeSleep = 28800 # 8hs = 480 min = 28800 s\
    
    dataset2 = dataset #.loc[dataset['outside_range'] == 0]
    
    data = dict()
    # basic transformations 
    #print("")
    #print("")
    print("")
    print("student_"+str(folder['folder'])+".csv", Counter(dataset['class']) )
    print("student_"+str(folder['folder'])+".csv", Counter(dataset2['class']) )
    
    unprocessedAwake = Counter(dataset['class'])['awake'] + unprocessedAwake
    processedAwake = Counter(dataset2['class'])['awake'] + processedAwake
    if("asleep" in Counter(dataset['class'])):
        unprocessedAsleep = Counter(dataset['class'])['asleep'] + unprocessedAsleep
        processedAsleep = Counter(dataset2['class'])['asleep'] + processedAsleep
print("Before pre-processing")
print("awake:",unprocessedAwake)
print("asleep:",unprocessedAsleep)
print("Total:",unprocessedAsleep+unprocessedAwake)
print()
print("After pre-processing")
print("awake:",processedAwake)
print("asleep:",processedAsleep)
print("Total:",processedAsleep+processedAwake)
# Out:
# Starting script test
#
#
# student_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs.csv Counter({'awake': 16341, 'asleep': 1652})
# student_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs.csv Counter({'awake': 16341, 'asleep': 1652})
#
# student_0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA.csv Counter({'awake': 8158, 'asleep': 3403})
# student_0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA.csv Counter({'awake': 8158, 'asleep': 3403})
#
# student_2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0.csv Counter({'awake': 2064, 'asleep': 1319})
# student_2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0.csv Counter({'awake': 2064, 'asleep': 1319})
#
# student_2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys.csv Counter({'awake': 12457, 'asleep': 6932})
# student_2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys.csv Counter({'awake': 12457, 'asleep': 6932})
#
# student_7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA.csv Counter({'awake': 2426, 'asleep': 327})
# ...

# %%
unprocessed = unprocessedAsleep+unprocessedAwake
processed = processedAsleep+processedAwake
percent = (100/unprocessed*processed)
print("Total= 100 /",unprocessed,"*",processed)
print("Total=",percent,"%")
print("Total=",100-percent,"%")
print("Diference=",unprocessed-processed)
print()
print("from", 467889/77561,"times to",368651/77561,"times")
print()
print()
print("awake states from 3 datasets without sleep records: ",1398+59+1712)
print()
instancesToRemove = 1398+59+1712
unprocessed = unprocessedAsleep+unprocessedAwake-instancesToRemove
processed = processedAsleep+processedAwake-instancesToRemove
percent = (100/unprocessed*processed)
print("Total= 100 /",unprocessed,"*",processed)
print("Total=",percent,"%")
print("Total=",100-percent,"%")
print("Diference=",unprocessed-processed)
print()
print("from", (467889-instancesToRemove)/77561,"times to",(368651-instancesToRemove)/77561,"times")
# Out:
# Total= 100 / 545450 * 545450
# Total= 100.0 %
# Total= 0.0 %
# Diference= 0
#
# from 6.032529235053699 times to 4.75304598960818 times
#
#
# awake states from 3 datasets without sleep records:  3169
#
# Total= 100 / 542281 * 542281
# Total= 100.0 %
# Total= 0.0 %
# Diference= 0
#
# from 5.99167107180155 times to 4.712187826356029 times
