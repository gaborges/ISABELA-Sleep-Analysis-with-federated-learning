# %%
import csv
import json
import pandas as pd
from datetime import datetime
import numpy as np
from os.path import exists

from collections import Counter

outputFolders = "../data_2019_processed/"
outputFoldersWeek = outputFolders + "w"

numberOfWeeks = 4 # each week will have the WeekTime, but the rest not


import warnings
warnings.filterwarnings("ignore")


#fileRaw = "allData.csv"
#fileNumeric = "-numeric.csv"
#fileNumericNormalized = "-numeric-normalized.csv"
#fileNumericClassification = "-numeric-classification.csv"
#fileNumericClassificationNormalized = "-classification-numeric-normalized.csv"

limitAwake = 64800 # 18 hs == 1080 min == 64800 s 
#limitAwake = 43200 # 12 hs == 1080 min == 64800 s 

#limitAwake = 86400 # 24 hs == 1080 min == 64800 s

# %%
# Dataframe of all datasets
# initialize list of lists
datasets = ['0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs',
            '0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA', 
            '2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0', 
            '2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys', 
            #['5FLZBTVAPwdq9QezHE2sVCJIs7p+r6mCemA2gp9jATk'], #does not have the file
            '7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA', 
            'a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4', 
            'ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc', 
            'Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U', 
            'CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA', 
            'DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc', 
            'DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA', 
            'dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY', 
            'HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo', 
            'jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw', 
            'JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I', 
            'K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8', 
            'oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q', 
            'pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM', 
            'PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc', 
            'QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ', 
            'rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw', 
            'RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI', 
            'SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4', 
            'VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is', 
            'Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw', 
            'XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA', 
            'YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw', 
            'ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM', 
            'ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY']
  
# Create the pandas DataFrame
folders = pd.DataFrame(datasets, columns=['folder'])

# %%
dataset = pd.read_csv(outputFolders+"student_oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q.csv")
#dataset = pd.read_csv(outputFolders+"student_ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM.csv")

dataset
# Out:
#        activity    location  distanceHome  showActuation     timestamp  \
# 0      Exercise  University             0          False  1.526321e+09
# 1         Still  University             0          False  1.526321e+09
# 2         Still  University             0          False  1.526322e+09
# 3       Unknown  University             0          False  1.526322e+09
# 4       Unknown  University             0          False  1.526322e+09
# ...         ...         ...           ...            ...           ...
# 21664   Tilting       House             0          False  1.528830e+09
# 21665     Still       House             0          False  1.528830e+09
# 21666     Still       House             0          False  1.528830e+09
# 21667     Still       House             0          False  1.528830e+09
# 21668     Still       House             0          False  1.528830e+09
#
#        time_to_next_alarm  sound  proximity  phone_lock  light  ...  \
# ...

# %%
dataset = pd.read_csv(outputFolders+"w0/student_oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q.csv")
#dataset = pd.read_csv(outputFolders+"student_ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM.csv")

dataset
# Out:
#       activity    location  distanceHome  showActuation   timestamp  \
# 0     Exercise  University             0          False  1526317085
# 1        Still  University             0          False  1526317793
# 2        Still  University             0          False  1526318003
# 3      Unknown  University             0          False  1526318033
# 4      Unknown  University             0          False  1526318063
# ...        ...         ...           ...            ...         ...
# 4772     Still  University             0          False  1526648034
# 4773     Still  University             0          False  1526648072
# 4774     Still  University             0          False  1526648349
# 4775     Still  University             0          False  1526648379
# 4776     Still  University             0          False  1526648571
#
#       time_to_next_alarm  sound  proximity  phone_lock  light day_of_week  \
# 0                   -1.0  32767          0  not locked      0      Monday
# ...

# %%
print("")
print("")
print("")
print("User: ","oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q")
print("")
print('location',Counter(dataset['location']))
print('activity',Counter(dataset['activity']))
print('day_of_week',Counter(dataset['day_of_week']))
print('light',Counter(dataset['light']),dataset['light'].sum())
print('sound',dataset['sound'].min(),dataset['sound'].sum())
print('time_sleeping',Counter(dataset['time_sleeping']))
print('sleep_time',Counter(dataset['sleep_time']))
print('wakeup_time',Counter(dataset['wakeup_time']))
print('proximity',Counter(dataset['proximity']))
print('class',Counter(dataset['class']))
print('sleep_time',Counter(dataset['sleep_time']))
print('wakeup_time',Counter(dataset['wakeup_time']))
print('timestamp',dataset['timestamp'][0],dataset['timestamp'][dataset.shape[0]-1])
print('time_to_next_alarm',Counter(dataset['time_to_next_alarm']))

print()

print("")
print("")
print("")
# Out:
# User:  oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q
#
# location Counter({'House': 3772, 'Other': 675, 'University': 330})
# activity Counter({'Still': 3890, 'Unknown': 334, 'In vehicle': 255, 'Exercise': 194, 'Tilting': 104})
# day_of_week Counter({'Tuesday': 1633, 'Wednesday': 1492, 'Thursday': 1044, 'Monday': 377, 'Friday': 231})
# light Counter({0: 4777}) 0
# sound 0 34030512
# time_sleeping Counter({61200: 2427, 25200: 716, 21600: 715, 10800: 704, 57600: 214, 28800: 1})
# sleep_time Counter({600: 3144, 300: 715, 1020: 704, 675: 214})
# wakeup_time Counter({180: 2427, 1020: 716, 660: 715, 1200: 704, 195: 214, 1080: 1})
# proximity Counter({1: 2673, 0: 2104})
# class Counter({'awake': 2791, 'asleep': 1986})
# sleep_time Counter({600: 3144, 300: 715, 1020: 704, 675: 214})
# wakeup_time Counter({180: 2427, 1020: 716, 660: 715, 1200: 704, 195: 214, 1080: 1})
# timestamp 1526317085 1526648571
# ...

# %%
#dataset.loc[dataset['class'] == "asleep"]
ff = dataset.loc[dataset['class'] == "asleep"]
#ff.iloc[[2]] # use the order from the array
ff
ff.iloc[0]['timestamp']
# Out:
# 1526317085

# %%
dataWithoutTreatment = []

for indexFolder, folder in folders.iterrows():
    currentFolder = folder['folder']
    
    weekData = []
    
    for i in range(0,numberOfWeeks):
        fileInput  = outputFoldersWeek+str(i)+"/student_"+currentFolder+".csv"
        fileOutput = outputFoldersWeek+str(i)+"/student_"+currentFolder+"_filtred.csv"
        
        dataset = pd.read_csv(fileInput)


        data = dict()
        # basic transformations 
        print("")
        print("")
        print("")
        print("student_"+currentFolder+".csv", Counter(dataset['class']) )
        print("")
        print('week',str(i))
        print('location',Counter(dataset['location']))
        print('activity',Counter(dataset['activity']))
        print('day_of_week',Counter(dataset['day_of_week']))
        print('light',dataset['light'].min(),dataset['light'].sum())
        print('sound',dataset['sound'].min(),dataset['sound'].sum())
        print('time_sleeping',Counter(dataset['time_sleeping']))
        print('sleep_time',Counter(dataset['sleep_time']))
        print('wakeup_time',Counter(dataset['wakeup_time']))
        print('proximity',Counter(dataset['proximity']))
        print('phone_lock',Counter(dataset['phone_lock']))
        print('class',Counter(dataset['class']))
        print('sleep_time',Counter(dataset['sleep_time']))
        print('wakeup_time',Counter(dataset['wakeup_time']))
        #print('timestamp',dataset['timestamp'][0],dataset['timestamp'][dataset.shape[0]-1])
        print("")
        #print('time_to_next_alarm',Counter(dataset['time_to_next_alarm']))
        print('time_to_next_alarm',dataset['time_to_next_alarm'].max())
        print("")
        print("")
        print("")


        #limitAwake = 64800 # 18 hs == 1080 min == 64800 s 
        #limitAwake = 86400
        #limitAfterAwake = 64800 # 18 hs == 1080 min == 64800 s 
        #limitBeforeSleep = 28800 # 8hs = 480 min = 28800 s\

        # ouside_range todos os dados com menos de timestamp - 64800
        dataset['outside_range']  = 0

        # first asleep timestamp
        nextAsleepTimeStamp = ff.iloc[0]['timestamp']
        lastAsleepTimeStamp = 0

        for index, content in dataset.iterrows():

            currentTimeStamp = content['timestamp']
            # outside_range before a timestamp
            if content['class'] == 'awake':
                if(currentTimeStamp < (nextAsleepTimeStamp-limitAwake) and currentTimeStamp > (lastAsleepTimeStamp+limitAwake) ):
                    dataset['outside_range'][index] = 1
            else:
                # change of asleep timestamp
                if(index < dataset.shape[0]-1):
                    if(dataset['class'][index+1] == 'awake'):
                        lastAsleepTimeStamp = currentTimeStamp # updates the last
                        # intermidiate variable
                        tess = dataset.iloc[index+1:].loc[dataset['class'] == "asleep"]
                        if(tess.shape[0] == 0): # used to treat the last nextAsleepTimeStamp
                            nextAsleepTimeStamp = 3790003633 # 2090-02-05 18:47:13
                        else:
                            # updates the next asleep
                            nextAsleepTimeStamp = dataset.iloc[index+1:].loc[dataset['class'] == "asleep"].iloc[0]['timestamp'] 

        #dataset = dataset.loc[dataset['outside_range'] == 0]

        print("Total excluídos: ",dataset.loc[dataset['outside_range'] == 1].shape[0])
        print("Total incluídos: ",dataset.loc[dataset['outside_range'] == 0].shape[0])
        print("Total excluídos do awake: ",dataset.loc[dataset['outside_range'] == 0].shape[0]-dataset.loc[dataset['class'] == "asleep"].shape[0])
        print("Total asleep:",dataset.loc[dataset['class'] == "asleep"].shape[0])
        print("Total: ",dataset.shape[0])
        #dataset.loc[dataset['outside_range'] == 1]
        
        weekData.append(dataset)
        
    dataWithoutTreatment.append(weekData)
# Out:
# student_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs.csv Counter({'awake': 1732, 'asleep': 677})
#
# week 0
# location Counter({'House': 1163, 'Other': 1135, 'University': 111})
# activity Counter({'Still': 1798, 'Exercise': 238, 'Unknown': 200, 'In vehicle': 104, 'Tilting': 69})
# day_of_week Counter({'Wednesday': 884, 'Tuesday': 646, 'Thursday': 638, 'Friday': 241})
# light 0 181954
# sound 0 14838563
# time_sleeping Counter({23419: 903, 64808: 662, 19849: 643, 18900: 200, 28800: 1})
# sleep_time Counter({285: 903, 1020: 662, 180: 643, 300: 200, 480: 1})
# wakeup_time Counter({675: 903, 660: 662, 510: 643, 615: 200, 960: 1})
# proximity Counter({5: 1552, 0: 857})
# phone_lock Counter({'locked': 1288, 'not locked': 1121})
# class Counter({'awake': 1732, 'asleep': 677})
# sleep_time Counter({285: 903, 1020: 662, 180: 643, 300: 200, 480: 1})
# wakeup_time Counter({675: 903, 660: 662, 510: 643, 615: 200, 960: 1})
#
# time_to_next_alarm 604320000.0
#
#
#
# Total excluídos:  0
# ...

# %%
dataTreated = []
excludedPerWeek = []
excludedPerClient = []

for i in range(0,numberOfWeeks):
    data = dict()
    data["week"] = i
    data["difference"] = 0
    data["awake"] = 0
    data["asleep"] = 0
    data["awake_filtered"] = 0
    data["asleep_filtered"] = 0
    excludedPerWeek.append(data)

unprocessedAwake, unprocessedAsleep = 0,0
processedAwake, processedAsleep = 0,0

for indexFolder in range(0, len(folders)):
    currentFolder = datasets[indexFolder]
    
    clientData = dataWithoutTreatment[indexFolder]
    
    clientMetrics = dict()
    clientMetrics["difference"] = 0
    clientMetrics["awake"] = 0
    clientMetrics["asleep"] = 0
    clientMetrics["awake_filtered"] = 0
    clientMetrics["asleep_filtered"] = 0
    
    print()
    print("student_"+currentFolder+".csv")
                         
    for i in range(0,numberOfWeeks):
        fileInput  = outputFoldersWeek+str(i)+"/student_"+currentFolder+".csv"
        fileOutput = outputFoldersWeek+str(i)+"/student_"+currentFolder+"_filtred.csv"
        
        # 
        weekData = clientData[i]

        weekDataFiltered = weekData.loc[weekData['outside_range'] == 0]
        
        print("Week",i)
        print("student_"+str(folder['folder'])+".csv", Counter(weekData['class']) )
        print("student_"+str(folder['folder'])+".csv", Counter(weekDataFiltered['class']) )

        # basic transformations 
        awakeCount  = Counter(weekData['class'])['awake']
        asleepCount = Counter(weekData['class'])['asleep']
        filteredAwakeCount  = Counter(weekDataFiltered['class'])['awake'] 
        filteredAsleepCount = Counter(weekDataFiltered['class'])['asleep'] 
        
        unprocessedAwake = awakeCount + unprocessedAwake
        processedAwake   = filteredAwakeCount + processedAwake
        
        difference = Counter(weekData['class'])['awake'] - Counter(weekDataFiltered['class'])['awake']
        print("Difference:",difference)
        
        if("asleep" in Counter(dataset['class'])):
            unprocessedAsleep = Counter(weekData['class'])['asleep'] + unprocessedAsleep
            processedAsleep = Counter(weekDataFiltered['class'])['asleep'] + processedAsleep
        
        data = excludedPerWeek[i] 
        data["difference"] = data["difference"] + difference
        data["awake"]      = data["awake"] + awakeCount
        data["asleep"]     = data["asleep"] + asleepCount
        data["awake_filtered"]  = data["awake_filtered"] + filteredAwakeCount
        data["asleep_filtered"] = data["asleep_filtered"] + filteredAsleepCount

        clientMetrics["difference"] = clientMetrics["difference"] + difference
        clientMetrics["awake"]      = clientMetrics["awake"] + awakeCount
        clientMetrics["asleep"]     = clientMetrics["asleep"] + asleepCount
        clientMetrics["awake_filtered"]  = clientMetrics["awake_filtered"] + filteredAwakeCount
        clientMetrics["asleep_filtered"] = clientMetrics["asleep_filtered"] + filteredAsleepCount
        
    excludedPerClient.append(clientMetrics)

print()                       
print("Before pre-processing")
print("awake:",unprocessedAwake)
print("asleep:",unprocessedAsleep)
print("Total:",unprocessedAsleep+unprocessedAwake)
print()
print("After pre-processing")
print("awake:",processedAwake)
print("asleep:",processedAsleep)
print("Total:",processedAsleep+processedAwake)
# Out:
# student_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs.csv
# Week 0
# student_ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY.csv Counter({'awake': 1732, 'asleep': 677})
# student_ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY.csv Counter({'awake': 1732, 'asleep': 677})
# Difference: 0
# Week 1
# student_ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY.csv Counter({'awake': 4174, 'asleep': 216})
# student_ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY.csv Counter({'awake': 4149, 'asleep': 216})
# Difference: 25
# Week 2
# student_ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY.csv Counter({'awake': 4338, 'asleep': 196})
# student_ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY.csv Counter({'awake': 4338, 'asleep': 196})
# Difference: 0
# Week 3
# student_ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY.csv Counter({'awake': 6097, 'asleep': 563})
# student_ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY.csv Counter({'awake': 6053, 'asleep': 563})
# Difference: 44
#
# ...

# %%
for data in excludedPerWeek:
    print(data)
# Out:
# {'week': 0, 'difference': 6688, 'awake': 56928, 'asleep': 18037, 'awake_filtered': 50240, 'asleep_filtered': 18037}
# {'week': 1, 'difference': 6822, 'awake': 107741, 'asleep': 27912, 'awake_filtered': 100919, 'asleep_filtered': 27912}
# {'week': 2, 'difference': 12685, 'awake': 110346, 'asleep': 20716, 'awake_filtered': 97661, 'asleep_filtered': 20716}
# {'week': 3, 'difference': 44570, 'awake': 171640, 'asleep': 32129, 'awake_filtered': 127070, 'asleep_filtered': 32129}

# %%
excludedPerClient
# Out:
# [{'difference': 69,
#   'awake': 16341,
#   'asleep': 1652,
#   'awake_filtered': 16272,
#   'asleep_filtered': 1652},
#  {'difference': 684,
#   'awake': 8158,
#   'asleep': 3403,
#   'awake_filtered': 7474,
#   'asleep_filtered': 3403},
#  {'difference': 825,
#   'awake': 2064,
#   'asleep': 1319,
#   'awake_filtered': 1239,
#   'asleep_filtered': 1319},
#  {'difference': 3915,
#   'awake': 16586,
#   'asleep': 2803,
#   'awake_filtered': 12671,
#   'asleep_filtered': 2803},
#  {'difference': 860,
#   'awake': 2426,
#   'asleep': 327,
#   'awake_filtered': 1566,
#   'asleep_filtered': 327},
#  {'difference': 5967,
#   'awake': 22241,
#   'asleep': 4326,
#   'awake_filtered': 16274,
#   'asleep_filtered': 4326},
#  {'difference': 3021,
#   'awake': 21466,
#   'asleep': 3068,
#   'awake_filtered': 18445,
#   'asleep_filtered': 3068},
#  {'difference': 2568,
#   'awake': 29483,
#   'asleep': 4419,
#   'awake_filtered': 26915,
#   'asleep_filtered': 4419},
#  {'difference': 4161,
# ...

# %%
446655 - 375890
# Out:
# 70765

# %% [markdown]
# # Export data

# %%
for indexFolder in range(0, len(folders)):
    currentFolder = datasets[indexFolder]
    
    
    print()
    print("student_"+currentFolder+".csv")
                         
    for i in range(0,numberOfWeeks):
        fileInput  = outputFoldersWeek+str(i)+"/student_"+currentFolder+".csv"
        fileOutput = outputFoldersWeek+str(i)+"/student_"+currentFolder+"_filtred.csv"
        
        # 
        weekData = clientData[i]

        weekDataFiltered = weekData.loc[weekData['outside_range'] == 0]
        
        print("Week",i)
        print(fileOutput)
        
        weekDataFiltered.to_csv(fileOutput, sep=',', encoding='utf-8', index=False)
# Out:
# student_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs.csv
# Week 0
# ../data_2019_processed/w0/student_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs_filtred.csv
# Week 1
# ../data_2019_processed/w1/student_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs_filtred.csv
# Week 2
# ../data_2019_processed/w2/student_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs_filtred.csv
# Week 3
# ../data_2019_processed/w3/student_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs_filtred.csv
#
# student_0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA.csv
# Week 0
# ../data_2019_processed/w0/student_0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA_filtred.csv
# Week 1
# ../data_2019_processed/w1/student_0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA_filtred.csv
# Week 2
# ../data_2019_processed/w2/student_0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA_filtred.csv
# Week 3
# ../data_2019_processed/w3/student_0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA_filtred.csv
#
# student_2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0.csv
# Week 0
# ...

# %%
weekData
# Out:
#      activity    location  distanceHome  showActuation   timestamp  \
# 0     Unknown       Other             0          False  1527945094
# 1       Still  University             0          False  1527945124
# 2     Unknown  University             0          False  1527945154
# 3     Unknown  University             0          False  1527945184
# 4     Unknown  University             0          False  1527945214
# ...       ...         ...           ...            ...         ...
# 9226    Still       House             0          False  1528888477
# 9227    Still       House             0          False  1528888688
# 9228    Still       House             0          False  1528888748
# 9229    Still       House             0          False  1528888778
# 9230  Tilting       House             0          False  1528888808
#
#       time_to_next_alarm  sound  proximity  phone_lock  light day_of_week  \
# 0            597180000.0      0          5  not locked    577    Saturday
# ...

# %%
CycleIndex = 0

biggerThan24hs = 0
lowerThan2hs = 0
sleepPeriods = 0
#trainDataPerCycle[cycle] inferredDataPerCycle
for index in range(0,len(dataWithoutTreatment)):
    print()
    print()
    print("Client: ",index) 
    print()
    
    clientData = dataWithoutTreatment[index]
    
    for i in range(0,numberOfWeeks):
        print("week",i) 
        
        weekData = clientData[i]
        weekDataFiltered = weekData.loc[weekData['outside_range'] == 0]
        awakeCount = weekData['class']
        
        countSleep = 0
        for indexData in range(0,len(awakeCount)):
            
            rowData = awakeCount[indexData]
            if (rowData == "awake"):
                if(countSleep > 0):
                    print("Time sleeping: ",countSleep,(countSleep*2/60))
                    if(countSleep <= 120):
                        lowerThan2hs = lowerThan2hs + 1
                    if(countSleep >= 172800):
                        biggerThan24hs = biggerThan24hs + 1
                    sleepPeriods = sleepPeriods + 1
                countSleep = 0
            else:
                countSleep = countSleep + 1
                
                
print()
print("24>",biggerThan24hs)
print("2<c",lowerThan2hs)
print("Total:",sleepPeriods)
# Out:
# Client:  0
#
# week 0
# Time sleeping:  554 18.466666666666665
# Time sleeping:  62 2.066666666666667
# Time sleeping:  61 2.033333333333333
# week 1
# Time sleeping:  13 0.43333333333333335
# Time sleeping:  1 0.03333333333333333
# Time sleeping:  57 1.9
# Time sleeping:  14 0.4666666666666667
# Time sleeping:  73 2.433333333333333
# Time sleeping:  21 0.7
# Time sleeping:  37 1.2333333333333334
# week 2
# Time sleeping:  33 1.1
# Time sleeping:  87 2.9
# Time sleeping:  12 0.4
# Time sleeping:  48 1.6
# Time sleeping:  3 0.1
# Time sleeping:  13 0.43333333333333335
# week 3
# Time sleeping:  201 6.7
# Time sleeping:  35 1.1666666666666667
# Time sleeping:  22 0.7333333333333333
# Time sleeping:  25 0.8333333333333334
# Time sleeping:  36 1.2
# Time sleeping:  4 0.13333333333333333
# Time sleeping:  31 1.0333333333333334
# Time sleeping:  22 0.7333333333333333
# Time sleeping:  18 0.6
# Time sleeping:  169 5.633333333333334
#
#
# Client:  1
#
# week 0
# ...

# %%
CycleIndex = 0
#trainDataPerCycle[cycle] inferredDataPerCycle
for index in range(0,len(dataWithoutTreatment)):
    print()
    print()
    print("Client: ",index) 
    print()
    
    clientData = dataWithoutTreatment[index]
    
    for i in range(0,numberOfWeeks):
        print("week",i) 
        
        weekData = clientData[i]
        weekDataFiltered = weekData.loc[weekData['outside_range'] == 0]
        awakeCount = weekData['class']
        
        countSleep = 0
        for indexData in range(0,len(awakeCount)):

            rowData = awakeCount[indexData]
            if (rowData == "awake"):
                if(countSleep > 0):
                    print("Time sleeping: ",countSleep,(countSleep*2/60))
                countSleep = 0
            else:
                countSleep = countSleep + 1
# Out:
# Client:  0
#
# week 0
# Time sleeping:  554 18.466666666666665
# Time sleeping:  62 2.066666666666667
# Time sleeping:  61 2.033333333333333
# week 1
# Time sleeping:  13 0.43333333333333335
# Time sleeping:  1 0.03333333333333333
# Time sleeping:  57 1.9
# Time sleeping:  14 0.4666666666666667
# Time sleeping:  73 2.433333333333333
# Time sleeping:  21 0.7
# Time sleeping:  37 1.2333333333333334
# week 2
# Time sleeping:  33 1.1
# Time sleeping:  87 2.9
# Time sleeping:  12 0.4
# Time sleeping:  48 1.6
# Time sleeping:  3 0.1
# Time sleeping:  13 0.43333333333333335
# week 3
# Time sleeping:  201 6.7
# Time sleeping:  35 1.1666666666666667
# Time sleeping:  22 0.7333333333333333
# Time sleeping:  25 0.8333333333333334
# Time sleeping:  36 1.2
# Time sleeping:  4 0.13333333333333333
# Time sleeping:  31 1.0333333333333334
# Time sleeping:  22 0.7333333333333333
# Time sleeping:  18 0.6
# Time sleeping:  169 5.633333333333334
#
#
# Client:  1
#
# week 0
# ...

# %% [markdown]
# # Weekly
#
# ## Before pre-processing
#
# awake: 446655
#
# asleep: 98794
#
# Total: 545449
#
#
# ## After pre-processing
#
# awake: 375890
#
# asleep: 98794
#
# Total: 474684
#
# # Whole data
#
# ## Before pre-processing
#
# awake: 446656
#
# asleep: 98794
#
# Total: 545450
#
#
# ## After pre-processing
#
# awake: 361986
#
# asleep: 98794
#
# Total: 460780
